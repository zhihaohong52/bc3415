# %% [markdown]
# <a href="https://colab.research.google.com/github/zhihaohong52/bc3415/blob/main/video_generator_stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers==0.19.0
# !pip install transformers scipy ftfy
# !pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !pip install imageio-ffmpeg

# %%
pip uninstall jax
# Out:
# Found existing installation: jax 0.4.33
# Uninstalling jax-0.4.33:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/jax-0.4.33.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jax/*
# Proceed (Y/n)? Y
#   Successfully uninstalled jax-0.4.33

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler

# %%
from diffusers.utils import export_to_video

# %%
pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# model.fp16.safetensors:   0%|          | 0.00/681M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/755 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/644 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/787 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# ...

# %%
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)

# %%
pipe.enable_model_cpu_offload()

# %%
pipe.enable_vae_slicing()

# %%
q = input("video: ")
# Out:
# video: pug running

# %%
v = pipe(q, num_frames=20).frames
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
v = export_to_video(v)

# %%
v
# Out:
# '/tmp/tmp5v7zvpeb.mp4'
